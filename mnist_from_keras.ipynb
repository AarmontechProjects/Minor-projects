# %%
# -*- coding: utf-8 -*-
"""Copy of mnist from keras

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1x8yHjN0VmEB9PKLOjSox1ehNSSdiiud-
"""

import tensorflow as tf

#Loading mnist data
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

#Normalize our image
"""x_train, x_test = x_train / 255.0 , x_test / 255.0"""

#changing y to one-hot
from keras.utils.np_utils import to_categorical
"""y_train, y_test = to_categorical(y_train), to_categorical(y_test)"""

x_train.shape, x_test.shape , y_train.shape, y_test.shape

x_train[1]

y_train[1]

#Normalize our image
x_train, x_test = x_train / 255.0 , x_test / 255.0

y  = [4,6,7,8]

x_train[1]

y_train, y_test = to_categorical(y_train), to_categorical(y_test)

y_train[1]

dir(tf.keras.datasets.mnist)

tf.keras.datasets.mnist.__path__

y_test.shape, y_test[15]

import matplotlib.pyplot as plt 
plt.imshow( x_train[1])

#Creating our network of neuralk network
#Flatten -> HiddenLayer -> Output -> Optimization
"""
model = tf.keras.models.Sequential([
                                    
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10)

]

)"""
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential

model = Sequential()

model.add(Flatten(input_shape = (28, 28)))
model.add(Dense(300, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(10))

#telling our model a way to learn, or we can say, way to correct itself to come to high accuarcy
model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Training our model
model.fit(x_train, y_train, epochs=5)

#Checking our model in test set
model.evaluate(x_test,  y_test, verbose=2)

model.summary()

model.predict( x_test[345:356])
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2040 - accuracy: 0.9394
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0839 - accuracy: 0.9749
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0586 - accuracy: 0.9813
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0432 - accuracy: 0.9861
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0342 - accuracy: 0.9889
# 313/313 - 0s - loss: 0.0887 - accuracy: 0.9757
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# ...
